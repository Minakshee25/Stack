# %%
#User function Template for python3

class Solution:
    def stack(self,n):
        self.arr = [0]*n
        self.top = -1
    def push(self,ele):
        self.top+=1
        self.arr[self.top] = ele
    def pop(self):
        ele = self.arr[self.top]
        self.top-=1
        return ele
    def stacktop(self):
        return self.arr[self.top]
    def nextLargerElement(self,arr,n):
        print(self.arr)

#{ 
#  Driver Code Starts
#Initial Template for Python 3
import atexit
import io
import sys

_INPUT_LINES = sys.stdin.read().splitlines()
input = iter(_INPUT_LINES).__next__
_OUTPUT_BUFFER = io.StringIO()
sys.stdout = _OUTPUT_BUFFER

@atexit.register

def write():
    sys.__stdout__.write(_OUTPUT_BUFFER.getvalue())

if __name__=='__main__':
    test_cases = int(input())
    for cases in range(test_cases) :
        n = int(input())

        a = list(map(int,input().strip().split()))
        obj = Solution()
        res = obj.nextLargerElement(a,n)
        for i in range (len (res)):
            print (res[i], end = " ")
        print ()
# } Driver Code Ends
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-7-fc4c3f2145c3> in <module>
#      35
#      36 if __name__=='__main__':
# ---> 37     test_cases = int(input())
#      38     for cases in range(test_cases) :
#      39         n = int(input())
#
# StopIteration:

# %%
res=[]
arr = [3, 4, 4, -1]
for i in range(len(arr)-2,-1,-1):
#     print(arr[i+1:])
    stack =[]
    for j in range(len(arr[i+1:])-1,-1,-1):
        stack.append(arr[i+1:][j])
    print(stack)
# Out:
# [-1]
# [-1, 4]
# [-1, 4, 4]

# %%
class Stack:
    def __init__(self,n):
        self.max_size=n
        self.arr = [0]*n
        self.top = -1
        return
    def push(self,ele):
        self.top+=1
        self.arr[self.top] = ele
        return
    def pop(self):
        if(self.top==-1):
            return -1
        else:
            ele = self.arr[self.top]
            self.top-=1
            return ele
    def stacktop(self):
        return self.arr[self.top]
    def isempty(self):
        if(self.top==-1):
            return 1
        else:
            return 0
class Solution:
    def nextLargerElement(self,arr,n):
        res=[-1]
        s1 = Stack(n)
        for i in range(n-2,-1,-1):
            print(arr[i])
            s1.push(arr[i+1])
            if(s1.pop()==-1):
                res.append(-1)
            while(s1.stacktop()<=arr[i]):
                if(s1.pop()==-1):
                    res.append(-1)
                    break
            if(s1.stacktop()>arr[i]):
                res.append(s1.stacktop())
            print(s1.arr)
        return res[::-1]
        
if __name__=='__main__':
    test_cases = int(input())
    for cases in range(test_cases) :
        n = int(input())
        a = list(map(int,input().strip().split()))
        obj = Solution()
        res = obj.nextLargerElement(a,n)
        for i in range (len (res)):
            print (res[i], end = " ")
        print ()
# Out:
# 1
# 5
# 6 8 0 1 3
# 1
# [3, 0, 0, 0, 0]
# 0
# [3, 1, 0, 0, 0]
# 8
# [3, 1, 0, 0, 0]
# 6
# [8, 1, 0, 0, 0]
# 8 -1 1 3 -1

# %%
class Stack:
    def __init__(self,n):
        self.max_size=n
        self.arr = [0]*n
        self.top = -1
        return
    def push(self,ele):
        self.top+=1
        self.arr[self.top] = ele
        return
    def pop(self):
        if(self.top==-1):
            return -1
        else:
            ele = self.arr[self.top]
            self.top-=1
            return ele
    def stacktop(self):
        return self.arr[self.top]
    def isempty(self):
        if(self.top==-1):
            return 1
        else:
            return 0
class Solution:
    def nextLargerElement(self,arr,n):
        res=[-1]
        s1 = Stack(n)
        for i in range(n-2,-1,-1):
            print(arr[i])
            s1.push(arr[i+1])
            while(s1.stacktop()<=arr[i]):
                print(s1.stacktop(),arr[i])
                if(s1.pop()==-1):
                    res.append(-1)
                    break
            if(s1.stacktop()>arr[i]):
                res.append(s1.stacktop())
            print(s1.arr)
        return res[::-1]
        
if __name__=='__main__':
    test_cases = int(input())
    for cases in range(test_cases) :
        n = int(input())
        a = list(map(int,input().strip().split()))
        obj = Solution()
        res = obj.nextLargerElement(a,n)
        for i in range (len (res)):
            print (res[i], end = " ")
        print ()
# Out:
# 1
# 5
# 6 8 0 1 3
# 1
# [3, 0, 0, 0, 0]
# 0
# [3, 1, 0, 0, 0]
# 8
# 0 8
# 1 8
# 3 8
# 0 8
# [3, 1, 0, 0, 0]
# 6
# [8, 1, 0, 0, 0]
# 8 -1 1 3 -1

# %%
#User function Template for python3


class Solution:
    def nextLargerElement(self,arr,n):
        #code here
        stack=[]
        v=[]
        for i in range(len(arr)-1,-1,-1):
            if len(stack)==0:
                v.append(-1)
            elif len(stack)>0 and stack[-1]>arr[i]:
                v.append(stack[-1])
            elif len(stack)>0 and stack[-1]<=arr[i]:
                while len(stack) and stack[-1]<=arr[i]:
                    stack.pop()
                if len(stack)==0:
                    v.append(-1)
                else:
                    v.append(stack[-1])
            stack.append(arr[i])
        return v[::-1]

#{ 
#  Driver Code Starts
#Initial Template for Python 3
import atexit
import io
import sys

_INPUT_LINES = sys.stdin.read().splitlines()
input = iter(_INPUT_LINES).__next__
_OUTPUT_BUFFER = io.StringIO()
sys.stdout = _OUTPUT_BUFFER

@atexit.register

def write():
    sys.__stdout__.write(_OUTPUT_BUFFER.getvalue())

if __name__ == '__main__':
    test_cases = int(input())
    for cases in range(test_cases) :
        n = int(input())

        a = list(map(int,input().strip().split()))
        obj = Solution()
        res = obj.nextLargerElement(a,n)
        for i in range (len (res)):
            print (res[i], end = " ")
        print ()
# } Driver Code Ends
